# %% [markdown]
# # This is a test

# %% [markdown]
# ## Steps to make this work:
#
# 1. Install VSCode (if you haven't already)
# 2. Install the following extensions from the VSCode Marketplace (they are all free):
# * Python
# * Python Debugger
# * Python Environments
# * Jupyter
# * Jupyter Cell Tags
# * Jupyter Keymap
# * Jupyter Notebook Renderers
# * Jupyter Slide Show
#
# 3. Set the kernel to a Python-based option. (check the top right corner to see the kernel you are using)
# 4. Run the code. Hopefully it works!

# %%
print("Hello World")
a = 6
print(a)
# Out:
# Hello World
# 7

# %% [markdown]
# * Press shift+enter to run a cell individually.
# * Click "Run All" to run all cells chronologically.
# * Separating code in cells like this enables data cleaners to observe changes in data as they occur.
# * NEVER manipulate the original data; always create a copy of it first.

# %%
a += 1
print(a)
# Out:
# 8

# %% [markdown]
# * If you run the above cell repeatedly, the number will continue to increment.
# * If you click "Run All" again, it will run the code again and it will NOT clear the existing variables.
# * To clear existing variables, click "Restart" to restart the kernel session and clear all memory from your session.
# * We will make a folder in the src folder for cleaning data.
# * Let me know if you have questions! :))
